# %%
import re

# %%
# Treat this as "\n" and not new line
r"\n"
# Out:
# '\\n'

# %%
my_folder = r"C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop\notes

# %%
# re.search
# Checks if a specified pattern exists within a string
result = re.search("pattern", r"string to contain a pattern")

# %%
print(result)
# Out:
# <re.Match object; span=(20, 27), match='pattern'>

# %%
result_search_2 = re.search("pattern",r"the phrase to find isn't in this string")
print(result_search_2)
# Out:
# None

# %%
#re.sub

# %%
# search for a specific text within a string and replace it
string_for_sub = r"sarah was able to help me find the items i needed"

# %%
subbed_string = re.sub("sarah", "sara", string_for_sub)
print(string_for_sub)
print(subbed_string)
# Out:
# sarah was able to help me find the items i needed
# sara was able to help me find the items i needed

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                   ]

# %%
patterns_to_find = r"sarah?"

# %%
sarahs_reviews = []
for string in customer_reviews:
    if (re.search(patterns_to_find, string)):
        sarahs_reviews.append(string)
print(sarahs_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
a_reviews = []
start_with_a = r"^a"
end_with_y = r"y$"

pattern = end_with_y

for string in customer_reviews:
    if (re.search(pattern, string)):
        a_reviews.append(string)
print(a_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %%
needwant_reviews = []
pattern = r"(need|want)ed"

for string in customer_reviews:
    if re.search(pattern, string):
        needwant_reviews.append(string)

print(needwant_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
no_punct_reviews = []
pattern = r"[^\w\s]"

for string in customer_reviews:
    no_punct_string = re.sub(pattern, "", string)
    no_punct_reviews.append(no_punct_string)
print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']
